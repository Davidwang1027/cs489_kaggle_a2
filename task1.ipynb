# %%
from pathlib import Path
from collections import Counter
import re

path = Path("sample/10k_sample.txt")
lines = path.read_text(encoding="utf-8").splitlines()

# Count lines that start with "the" (case-insensitive)
the_start_count = sum(1 for line in lines if line.lower().startswith("the"))

words = ["dogs", "cats", "mice", "chase", "like"]
word_counts = Counter()

for line in lines:
    tokens = re.findall(r"\b\w+\b", line.lower())
    word_counts.update(tokens)

print(f"Lines starting with 'the': {the_start_count}")
print("\nWord counts:")
for w in words:
    print(f"{w}: {word_counts[w]}")
# Out:
# Lines starting with 'the': 3684
#
# Word counts:
# dogs: 4152
# cats: 9498
# mice: 6350
# chase: 7398
# like: 2600

# %%
from pathlib import Path
from collections import Counter
import re

path = Path("sample/5k_sample.txt")
lines = path.read_text(encoding="utf-8").splitlines()

# Count lines that start with "the" (case-insensitive)
the_start_count = sum(1 for line in lines if line.lower().startswith("the"))

words = ["dogs", "cats", "mice", "chase", "like"]
word_counts = Counter()

for line in lines:
    tokens = re.findall(r"\b\w+\b", line.lower())
    word_counts.update(tokens)

print(f"Lines starting with 'the': {the_start_count}")
print("\nWord counts:")
for w in words:
    print(f"{w}: {word_counts[w]}")
# Out:
# Lines starting with 'the': 1822
#
# Word counts:
# dogs: 2049
# cats: 4756
# mice: 3196
# chase: 3701
# like: 1299
